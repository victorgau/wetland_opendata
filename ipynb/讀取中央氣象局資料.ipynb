# %%
import requests

# %%
# 請用您自己的授權碼
url = "https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/C-B0024-002?Authorization=CWB-XXXXXXXX-XXXX-XXXX-XXXX-XXXXXXXXXXXX&downloadType=WEB&format=JSON"

# %%
data = requests.get(url).json()

# %%
data['cwbopendata']['dataset']['location'][0]

# %%
url1 = "https://e-service.cwb.gov.tw/wdps/obs/state.htm"

# %%
import pandas as pd

# %%
dfs = pd.read_html(url1, skiprows=1, header=0)

# %%
dfs[0].head()
# Out:
#        站號      站名 海拔高度(m)  ...  原站號  新站號 Unnamed: 12
# 0  466850  五分山雷達站     756  ...  NaN  NaN         NaN
# 1  466880      板橋     9.7  ...  NaN  NaN         NaN
# 2  466900      淡水      19  ...  NaN  NaN         NaN
# 3  466910      鞍部   837.6  ...  NaN  NaN         NaN
# 4  466920      臺北     5.3  ...  NaN  NaN         NaN
#
# [5 rows x 13 columns]

# %%
dfs[0][dfs[0]["站號"]=="二、已撤銷測站："]
# Out:
#            站號   站名 海拔高度(m)   經度   緯度  ... 撤站日期   備註  原站號  新站號 Unnamed: 12
# 610  二、已撤銷測站：  NaN     NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN         NaN
#
# [1 rows x 13 columns]

# %%
df = dfs[0].iloc[:610]

# %%
df.tail()
# Out:
#          站號    站名 海拔高度(m)  ...     原站號  新站號 Unnamed: 12
# 605  C1Z130    銅門     187  ...  C1T860  NaN         NaN
# 606  C1Z140    荖溪     950  ...     NaN  NaN         NaN
# 607  C1Z240  中平林道    1163  ...     NaN  NaN         NaN
# 608     NaN   NaN     NaN  ...     NaN  NaN         NaN
# 609     NaN   NaN     NaN  ...     NaN  NaN         NaN
#
# [5 rows x 13 columns]

# %%
df.drop([608, 609],inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.tail()
# Out:
#          站號    站名 海拔高度(m)  ...     原站號  新站號 Unnamed: 12
# 603  C1Z110    三棧     680  ...  C1Z090  NaN         NaN
# 604  C1Z120    壽豐      62  ...  C1T860  NaN         NaN
# 605  C1Z130    銅門     187  ...  C1T860  NaN         NaN
# 606  C1Z140    荖溪     950  ...     NaN  NaN         NaN
# 607  C1Z240  中平林道    1163  ...     NaN  NaN         NaN
#
# [5 rows x 13 columns]

# %%
df[df['城市']=="高雄市"]
# Out:
#          站號        站名 海拔高度(m)  ...     原站號  新站號 Unnamed: 12
# 18   467440        高雄     2.3  ...     NaN  NaN         NaN
# 379  C0V210        復興     734  ...  C1V210  NaN         NaN
# 380  C0V250        甲仙     298  ...     NaN  NaN         NaN
# 381  C0V260        月眉     126  ...  C1V260  NaN         NaN
# 382  C0V310        美濃      46  ...     NaN  NaN         NaN
# 383  C0V350        溪埔      36  ...  C1V350  NaN         NaN
# 384  C0V360        內門      94  ...  C1V360  NaN         NaN
# 385  C0V370       古亭坑      74  ...     NaN  NaN         NaN
# 386  C0V400       阿公店      56  ...  C1V400  NaN         NaN
# 387  C0V440        鳳山      27  ...  C1V440  NaN         NaN
# 388  C0V450        鳳森      51  ...  C1V451  NaN         NaN
# 389  C0V490        新興      20  ...     NaN  NaN         NaN
# 390  C0V500        旗津       6  ...     NaN  NaN         NaN
# 391  C0V530        阿蓮      34  ...  C1V530  NaN         NaN
# 392  C0V610        梓官      22  ...     NaN  NaN         NaN
# ...
